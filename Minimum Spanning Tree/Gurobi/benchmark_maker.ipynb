# %%
# %run Function_set_gurobi.ipynb
import networkx as nx
import numpy as np
from collections import defaultdict
import random
from numpy import random
import matplotlib.pyplot as plt
import json
import os
# Out:
# <style>.container { width:100% !important; }</style>

# %%
class NumpyEncoder(json.JSONEncoder):
    """ Special json encoder for numpy types """
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        return json.JSONEncoder.default(self, obj)

# %%
bench_num = 10

Width = 3
Height = 3
D = 0.85


current_directory = os.getcwd()
    
next_dir = "W%d_H%d_Benchmark"%(Width, Height)
    
final_directory = os.path.join(current_directory, next_dir)
    
print(final_directory)
    
if not os.path.exists(final_directory):
    os.makedirs(final_directory)


for i in range(bench_num):  
    
    network,pos = Make_Question(Width, Height, Density = D, option = "1-norm", distance = 1)
    
    plt.figure(i)
    
    G, compelete_label, graph = complete_Graph(network,pos)
    
    
    np.save("W%d_H%d_Benchmark/W%d_H%d_Benchmark%d.npy"%(Width, Height, Width, Height, i) , network)
    
    
    # create json object from dictionary
    dumped = json.dumps(pos, cls=NumpyEncoder)
    print(dumped)

    # open file for writing, "w" 
    
    with open("W%d_H%d_Benchmark/W%d_H%d_Benchmark%d.json"%(Width, Height, Width, Height, i), 'w') as f:
        json.dump(dumped, f)

    # write json object to file
    #f.write(json)

    # close file
    f.close()
# Out:
# F:\UoH\UoH_code\Minimum Spanning Tree\Gurobi\W3_H3_Benchmark
# {"0": [6.7, 6], "1": [4, 4], "2": [2, 4], "3": [4, 2], "4": [2, 2], "5": [0, 2], "6": [4, 0], "7": [2, 0]}
# {"0": [6.7, 6], "1": [4, 4], "2": [2, 4], "3": [4, 2], "4": [2, 2], "5": [0, 2], "6": [2, 0], "7": [0, 0]}
# {"0": [6.7, 6], "1": [4, 4], "2": [2, 4], "3": [4, 2], "4": [2, 2], "5": [0, 2], "6": [2, 0], "7": [0, 0]}
# {"0": [6.7, 6], "1": [2, 4], "2": [0, 4], "3": [4, 2], "4": [2, 2], "5": [0, 2], "6": [2, 0], "7": [0, 0]}
# {"0": [6.7, 6], "1": [4, 4], "2": [2, 4], "3": [2, 2], "4": [0, 2], "5": [4, 0], "6": [2, 0], "7": [0, 0]}
# {"0": [6.7, 6], "1": [4, 4], "2": [2, 4], "3": [4, 2], "4": [2, 2], "5": [0, 2], "6": [4, 0], "7": [2, 0]}
# {"0": [6.7, 6], "1": [4, 4], "2": [2, 4], "3": [4, 2], "4": [2, 2], "5": [0, 2], "6": [4, 0], "7": [2, 0]}
# {"0": [6.7, 6], "1": [4, 4], "2": [2, 4], "3": [4, 2], "4": [2, 2], "5": [0, 2], "6": [4, 0], "7": [2, 0]}
# {"0": [6.7, 6], "1": [2, 4], "2": [0, 4], "3": [4, 2], "4": [2, 2], "5": [0, 2], "6": [2, 0], "7": [0, 0]}
# {"0": [6.7, 6], "1": [2, 4], "2": [4, 2], "3": [2, 2], "4": [0, 2], "5": [4, 0], "6": [2, 0], "7": [0, 0]}

# %%
#
#W4H3 W3H4 D=0.7
# rest  0.85
